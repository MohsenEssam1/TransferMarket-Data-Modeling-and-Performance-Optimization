# %%
pip install pandas
# Out:
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: pandas in c:\users\mohse\anaconda3\lib\site-packages (2.0.3)
# ...
# WARNING: Skipping c:\Users\mohse\anaconda3\Lib\site-packages\jupyterlab-3.6.3.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping c:\Users\mohse\anaconda3\Lib\site-packages\jupyterlab_server-2.22.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping c:\Users\mohse\anaconda3\Lib\site-packages\jupyter_server-2.5.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping c:\Users\mohse\anaconda3\Lib\site-packages\nbconvert-6.5.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping c:\Users\mohse\anaconda3\Lib\site-packages\notebook-6.5.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping c:\Users\mohse\anaconda3\Lib\site-packages\panel-1.1.0.dist-info due to invalid metadata entry 'name'
# ...

# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_csv("D:/a trainning iti\hadoop\project\data\players.csv")
df.head()
# Out:
#    player_id first_name     last_name                name  last_season  \
# 0         10   Miroslav         Klose      Miroslav Klose         2015
# 1         26      Roman  Weidenfeller  Roman Weidenfeller         2017
# 2         65    Dimitar      Berbatov    Dimitar Berbatov         2015
# 3         77        NaN         Lúcio               Lúcio         2012
# 4         80        Tom        Starke          Tom Starke         2017
#
#    current_club_id         player_code    country_of_birth city_of_birth  \
# 0              398      miroslav-klose              Poland         Opole
# 1               16  roman-weidenfeller             Germany          Diez
# 2             1091    dimitar-berbatov            Bulgaria   Blagoevgrad
# 3              506               lucio              Brazil      Brasília
# 4               27          tom-starke  East Germany (GDR)       Freital
#
#   country_of_citizenship  ...   foot height_in_cm contract_expiration_date  \
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df[df['player_id']==0]
# Out:
#        player_id first_name last_name name  last_season  current_club_id  \
# 32489          0          0         0    0            0                0
#
#       player_code country_of_birth city_of_birth country_of_citizenship  ...  \
# 32489           0                0             0                      0  ...
#
#       foot height_in_cm contract_expiration_date agent_name  image_url url  \
# 32489    0          0.0                        0          0          0   0
#
#       current_club_domestic_competition_id current_club_name  \
# 32489                                    0                 0
#
#       market_value_in_eur highest_market_value_in_eur
# 32489                 0.0                         0.0
#
# [1 rows x 23 columns]

# %%
df.loc[len(df)]=0

# %%
df['player_id'].duplicated().sum()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# player_id                                   0
# first_name                               2057
# last_name                                   0
# name                                        0
# last_season                                 0
# current_club_id                             0
# player_code                                 0
# country_of_birth                         2789
# city_of_birth                            2443
# country_of_citizenship                    383
# date_of_birth                              47
# sub_position                              182
# position                                    0
# foot                                     2541
# height_in_cm                             2248
# contract_expiration_date                12116
# agent_name                              15997
# image_url                                   0
# url                                         0
# current_club_domestic_competition_id        0
# ...

# %% [markdown]
#  # club table

# %%
df1= pd.read_csv("D:/a trainning iti\hadoop\project\data\clubs.csv")
df1.head()
# Out:
#    club_id          club_code                             name  \
# 0      105    sv-darmstadt-98                  SV Darmstadt 98
# 1    11127  ural-ekaterinburg               Ural Yekaterinburg
# 2      114  besiktas-istanbul        Beşiktaş Jimnastik Kulübü
# 3       12             as-rom       Associazione Sportiva Roma
# 4      148  tottenham-hotspur  Tottenham Hotspur Football Club
#
#   domestic_competition_id  total_market_value  squad_size  average_age  \
# 0                      L1                 NaN          27         25.6
# 1                     RU1                 NaN          30         26.5
# 2                     TR1                 NaN          31         26.5
# 3                     IT1                 NaN          25         26.1
# 4                     GB1                 NaN          30         25.1
#
#    foreigners_number  foreigners_percentage  national_team_players  \
# 0                 13                   48.1                      1
# ...

# %%
df1.duplicated().sum()
# Out:
# 0

# %%
df1.isna().sum()
# Out:
# club_id                      0
# club_code                    0
# name                         0
# domestic_competition_id      0
# total_market_value         439
# squad_size                   0
# average_age                 38
# foreigners_number            0
# foreigners_percentage       49
# national_team_players        0
# stadium_name                 0
# stadium_seats                0
# net_transfer_record          0
# coach_name                 439
# last_season                  0
# filename                     0
# url                          0
# dtype: int64

# %%
df1[df1['club_id']==0]
# Out:
#      club_id club_code name domestic_competition_id  total_market_value  \
# 439        0         0    0                       0                 0.0
#
#      squad_size  average_age  foreigners_number  foreigners_percentage  \
# 439           0          0.0                  0                    0.0
#
#      national_team_players stadium_name  stadium_seats net_transfer_record  \
# 439                      0            0              0                   0
#
#      coach_name  last_season filename url
# 439         0.0            0        0   0

# %%
df1.loc[len(df1)]=0

# %% [markdown]
# # transfer

# %%
transfer= pd.read_csv("D:/a trainning iti\hadoop\project\data/transfers.csv")

# %%
transfer.isna().sum()
# Out:
# player_id                  0
# transfer_date              0
# transfer_season            0
# from_club_id               0
# to_club_id                 0
# from_club_name             0
# to_club_name               0
# transfer_fee           27469
# market_value_in_eur    30011
# player_name                0
# dtype: int64

# %%
transfer[transfer['market_value_in_eur'].isna()==True].head()
# Out:
#      player_id transfer_date transfer_season  from_club_id  to_club_id  \
# 38      800919    2025-07-01           25/26          8815         206
# 45     1003295    2025-07-01           25/26         15642        1177
# 508     717413    2025-06-30           24/25         49364       14300
# 591     825834    2025-06-30           24/25          7179       68403
# 598     836576    2025-06-30           24/25         49675         369
#
#      from_club_name  to_club_name  transfer_fee  market_value_in_eur  \
# 38   Bröndby IF U19    Bröndby IF           NaN                  NaN
# 45    Silkeborg U19  Silkeborg IF           NaN                  NaN
# 508        Ingulets  Shakhtar U19           0.0                  NaN
# 591         Tondela   Estoril U23           0.0                  NaN
# 598      Hilleröd F     Lyngby BK           0.0                  NaN
#
#          player_name
# 38      Lukas Larsen
# 45    Julius Nielsen
# 508  Oleg Pushkaryov
# 591    Rodrigo Ramos
# ...

# %%
transfer = transfer.merge(df[['player_id', 'market_value_in_eur']], on='player_id', how='left', suffixes=('', '_df'))

# %%
transfer
# Out:
#        player_id transfer_date transfer_season  from_club_id  to_club_id  \
# 0         195778    2026-06-30           25/26            79          27
# 1         569033    2026-06-30           25/26            39          27
# 2         626913    2026-06-30           25/26           398         380
# 3        1047109    2026-06-30           25/26          2672         265
# 4         145988    2026-01-17           25/26         78435         141
# ...          ...           ...             ...           ...         ...
# 78806      35207    1995-07-01           95/96         42281       11896
# 78807      22141    1994-07-01           94/95         59178       29463
# 78808      33829    1994-07-01           94/95         58405       53957
# 78809      40680    1994-07-01           94/95         47320       47318
# 78810      61989    1993-07-01           93/94         55345       55343
#
#         from_club_name     to_club_name  transfer_fee  market_value_in_eur  \
# ...

# %%
transfer['market_value_in_eur'] = transfer['market_value_in_eur'].fillna(transfer['market_value_in_eur_df'])

# %%
transfer.head()
# Out:
#    player_id transfer_date transfer_season  from_club_id  to_club_id  \
# 0     195778    2026-06-30           25/26            79          27
# 1     569033    2026-06-30           25/26            39          27
# 2     626913    2026-06-30           25/26           398         380
# 3    1047109    2026-06-30           25/26          2672         265
# 4     145988    2026-01-17           25/26         78435         141
#
#    from_club_name   to_club_name  transfer_fee  market_value_in_eur  \
# 0   VfB Stuttgart  Bayern Munich           0.0           12000000.0
# 1  1.FSV Mainz 05  Bayern Munich           0.0            4000000.0
# 2           Lazio    Salernitana           0.0           15000000.0
# 3  APO Levadiakos  Panathinaikos           0.0             200000.0
# 4       Charlotte    Galatasaray           0.0            8000000.0
#
#        player_name  market_value_in_eur_df
# 0  Alexander Nübel              12000000.0
# 1     Armindo Sieb               4000000.0
# ...

# %%
transfer = transfer.drop(columns=['market_value_in_eur_df'])

# %%
transfer.isna().sum()
# Out:
# player_id                  0
# transfer_date              0
# transfer_season            0
# from_club_id               0
# to_club_id                 0
# from_club_name             0
# to_club_name               0
# transfer_fee           27469
# market_value_in_eur     1524
# player_name                0
# dtype: int64

# %%
transfer.duplicated().sum()
# Out:
# 0

# %%
a=(transfer['transfer_fee'] == 0).sum()
a
# Out:
# 42019

# %%
transfer['transfer_fee'].isna().sum()
# Out:
# 27469

# %%
transfer['transfer_fee']=transfer['transfer_fee'].fillna(0)

# %%
transfer['market_value_in_eur']=transfer['market_value_in_eur'].fillna(0)

# %%
transfer.isna().sum()
# Out:
# player_id              0
# transfer_date          0
# transfer_season        0
# from_club_id           0
# to_club_id             0
# from_club_name         0
# to_club_name           0
# transfer_fee           0
# market_value_in_eur    0
# player_name            0
# dtype: int64

# %%
transfer.head()
# Out:
#    player_id transfer_date transfer_season  from_club_id  to_club_id  \
# 0     195778    2026-06-30           25/26            79          27
# 1     569033    2026-06-30           25/26            39          27
# 2     626913    2026-06-30           25/26           398         380
# 3    1047109    2026-06-30           25/26          2672         265
# 4     145988    2026-01-17           25/26         78435         141
#
#    from_club_name   to_club_name  transfer_fee  market_value_in_eur  \
# 0   VfB Stuttgart  Bayern Munich           0.0           12000000.0
# 1  1.FSV Mainz 05  Bayern Munich           0.0            4000000.0
# 2           Lazio    Salernitana           0.0           15000000.0
# 3  APO Levadiakos  Panathinaikos           0.0             200000.0
# 4       Charlotte    Galatasaray           0.0            8000000.0
#
#        player_name
# 0  Alexander Nübel
# 1     Armindo Sieb
# 2      Boulaye Dia
# 3  Georgios Katris
# 4    Wilfried Zaha

# %%
transfer.drop(columns=['from_club_name','to_club_name','player_name'],inplace=True)

# %%
transfer.head()
# Out:
#    player_id transfer_date transfer_season  from_club_id  to_club_id  \
# 0     195778    2026-06-30           25/26            79          27
# 1     569033    2026-06-30           25/26            39          27
# 2     626913    2026-06-30           25/26           398         380
# 3    1047109    2026-06-30           25/26          2672         265
# 4     145988    2026-01-17           25/26         78435         141
#
#    transfer_fee  market_value_in_eur
# 0           0.0           12000000.0
# 1           0.0            4000000.0
# 2           0.0           15000000.0
# 3           0.0             200000.0
# 4           0.0            8000000.0

# %%
df.head()
# Out:
#    player_id first_name     last_name                name  last_season  \
# 0         10   Miroslav         Klose      Miroslav Klose         2015
# 1         26      Roman  Weidenfeller  Roman Weidenfeller         2017
# 2         65    Dimitar      Berbatov    Dimitar Berbatov         2015
# 3         77        NaN         Lúcio               Lúcio         2012
# 4         80        Tom        Starke          Tom Starke         2017
#
#    current_club_id         player_code    country_of_birth city_of_birth  \
# 0              398      miroslav-klose              Poland         Opole
# 1               16  roman-weidenfeller             Germany          Diez
# 2             1091    dimitar-berbatov            Bulgaria   Blagoevgrad
# 3              506               lucio              Brazil      Brasília
# 4               27          tom-starke  East Germany (GDR)       Freital
#
#   country_of_citizenship  ...   foot height_in_cm contract_expiration_date  \
# ...

# %%
df1.head()
# Out:
#    club_id          club_code                             name  \
# 0      105    sv-darmstadt-98                  SV Darmstadt 98
# 1    11127  ural-ekaterinburg               Ural Yekaterinburg
# 2      114  besiktas-istanbul        Beşiktaş Jimnastik Kulübü
# 3       12             as-rom       Associazione Sportiva Roma
# 4      148  tottenham-hotspur  Tottenham Hotspur Football Club
#
#   domestic_competition_id  total_market_value  squad_size  average_age  \
# 0                      L1                 NaN          27         25.6
# 1                     RU1                 NaN          30         26.5
# 2                     TR1                 NaN          31         26.5
# 3                     IT1                 NaN          25         26.1
# 4                     GB1                 NaN          30         25.1
#
#    foreigners_number  foreigners_percentage  national_team_players  \
# 0                 13                   48.1                      1
# ...

# %%
transfer.to_csv(r'D:/a trainning iti/hadoop/project/new_data/new_transfer.csv', index=False)

# %%
df.to_csv(r'D:\a trainning iti\hadoop\project\new_data\new_players.csv',index=False)

# %%
df1.to_csv(r'D:\a trainning iti\hadoop\project\new_data\new_clubs.csv',index=False)

# %% [markdown]
# # competations

# %%
competations = pd.read_csv("D:/a trainning iti\hadoop\project\data\competitions.csv")
competations.head()
# Out:
#   competition_id               competition_code  \
# 0            CIT                      italy-cup
# 1           NLSC           johan-cruijff-schaal
# 2            GRP                kypello-elladas
# 3           POSU  supertaca-candido-de-oliveira
# 4           RUSS              russian-super-cup
#
#                             name            sub_type          type  \
# 0                      italy-cup        domestic_cup  domestic_cup
# 1           johan-cruijff-schaal  domestic_super_cup         other
# 2                kypello-elladas        domestic_cup  domestic_cup
# 3  supertaca-candido-de-oliveira  domestic_super_cup         other
# 4              russian-super-cup  domestic_super_cup         other
#
#    country_id country_name domestic_league_code confederation  \
# 0          75        Italy                  IT1        europa
# 1         122  Netherlands                  NL1        europa
# 2          56       Greece                  GR1        europa
# ...

# %%
competations['competition_id'].duplicated().sum()
# Out:
# 0

# %%
competations.isna().sum()
# Out:
# competition_id              0
# competition_code            0
# name                        0
# sub_type                    0
# type                        0
# country_id                  0
# country_name                8
# domestic_league_code        8
# confederation               0
# url                         0
# is_major_national_league    0
# dtype: int64

# %%
competations['competition_id_sk']= np.arange(1,len(competations)+1)

# %%
competations.head()
# Out:
#   competition_id               competition_code  \
# 0            CIT                      italy-cup
# 1           NLSC           johan-cruijff-schaal
# 2            GRP                kypello-elladas
# 3           POSU  supertaca-candido-de-oliveira
# 4           RUSS              russian-super-cup
#
#                             name            sub_type          type  \
# 0                      italy-cup        domestic_cup  domestic_cup
# 1           johan-cruijff-schaal  domestic_super_cup         other
# 2                kypello-elladas        domestic_cup  domestic_cup
# 3  supertaca-candido-de-oliveira  domestic_super_cup         other
# 4              russian-super-cup  domestic_super_cup         other
#
#    country_id country_name domestic_league_code confederation  \
# 0          75        Italy                  IT1        europa
# 1         122  Netherlands                  NL1        europa
# 2          56       Greece                  GR1        europa
# ...

# %% [markdown]
# # appearance

# %%
appearance = pd.read_csv("D:/a trainning iti\hadoop\project\data/appearances.csv")
appearance.head()
# Out:
#     appearance_id  game_id  player_id  player_club_id  player_current_club_id  \
# 0   2231978_38004  2231978      38004             853                     235
# 1   2233748_79232  2233748      79232            8841                    2698
# 2   2234413_42792  2234413      42792            6251                     465
# 3   2234418_73333  2234418      73333            1274                    6646
# 4  2234421_122011  2234421     122011             195                    3008
#
#          date       player_name competition_id  yellow_cards  red_cards  \
# 0  2012-07-03  Aurélien Joachim            CLQ             0          0
# 1  2012-07-05    Ruslan Abyshov            ELQ             0          0
# 2  2012-07-05       Sander Puri            ELQ             0          0
# 3  2012-07-05   Vegar Hedenstad            ELQ             0          0
# 4  2012-07-05  Markus Henriksen            ELQ             0          0
#
#    goals  assists  minutes_played
# ...

# %%
appearance= appearance.merge(competations[['competition_id','competition_id_sk']],how='left',on='competition_id')
appearance.head()
# Out:
#     appearance_id  game_id  player_id  player_club_id  player_current_club_id  \
# 0   2231978_38004  2231978      38004             853                     235
# 1   2233748_79232  2233748      79232            8841                    2698
# 2   2234413_42792  2234413      42792            6251                     465
# 3   2234418_73333  2234418      73333            1274                    6646
# 4  2234421_122011  2234421     122011             195                    3008
#
#          date       player_name competition_id  yellow_cards  red_cards  \
# 0  2012-07-03  Aurélien Joachim            CLQ             0          0
# 1  2012-07-05    Ruslan Abyshov            ELQ             0          0
# 2  2012-07-05       Sander Puri            ELQ             0          0
# 3  2012-07-05   Vegar Hedenstad            ELQ             0          0
# 4  2012-07-05  Markus Henriksen            ELQ             0          0
#
#    goals  assists  minutes_played  competition_id_sk
# ...

# %%
appearance['competition_id']=appearance['competition_id_sk']

# %%
appearance.drop('competition_id_sk', axis=1, inplace=True)

# %%
appearance.head()
# Out:
#     appearance_id  game_id  player_id  player_club_id  player_current_club_id  \
# 0   2231978_38004  2231978      38004             853                     235
# 1   2233748_79232  2233748      79232            8841                    2698
# 2   2234413_42792  2234413      42792            6251                     465
# 3   2234418_73333  2234418      73333            1274                    6646
# 4  2234421_122011  2234421     122011             195                    3008
#
#          date       player_name  competition_id  yellow_cards  red_cards  \
# 0  2012-07-03  Aurélien Joachim              39             0          0
# 1  2012-07-05    Ruslan Abyshov              19             0          0
# 2  2012-07-05       Sander Puri              19             0          0
# 3  2012-07-05   Vegar Hedenstad              19             0          0
# 4  2012-07-05  Markus Henriksen              19             0          0
#
#    goals  assists  minutes_played  competition_id_sk
# ...

# %%
appearance.head()
# Out:
#     appearance_id  game_id  player_id  player_club_id  player_current_club_id  \
# 0   2231978_38004  2231978      38004             853                     235
# 1   2233748_79232  2233748      79232            8841                    2698
# 2   2234413_42792  2234413      42792            6251                     465
# 3   2234418_73333  2234418      73333            1274                    6646
# 4  2234421_122011  2234421     122011             195                    3008
#
#          date       player_name  competition_id  yellow_cards  red_cards  \
# 0  2012-07-03  Aurélien Joachim              39             0          0
# 1  2012-07-05    Ruslan Abyshov              19             0          0
# 2  2012-07-05       Sander Puri              19             0          0
# 3  2012-07-05   Vegar Hedenstad              19             0          0
# 4  2012-07-05  Markus Henriksen              19             0          0
#
#    goals  assists  minutes_played
# ...

# %%
appearance.drop('player_name', axis=1, inplace=True)

# %%
appearance.head()
# Out:
#     appearance_id  game_id  player_id  player_club_id  player_current_club_id  \
# 0   2231978_38004  2231978      38004             853                     235
# 1   2233748_79232  2233748      79232            8841                    2698
# 2   2234413_42792  2234413      42792            6251                     465
# 3   2234418_73333  2234418      73333            1274                    6646
# 4  2234421_122011  2234421     122011             195                    3008
#
#          date  competition_id  yellow_cards  red_cards  goals  assists  \
# 0  2012-07-03              39             0          0      2        0
# 1  2012-07-05              19             0          0      0        0
# 2  2012-07-05              19             0          0      0        0
# 3  2012-07-05              19             0          0      0        0
# 4  2012-07-05              19             0          0      0        1
#
#    minutes_played
# 0              90
# 1              90
# ...

# %%
appearance.to_csv(r'D:\a trainning iti\hadoop\project\new_data\new_appearnace.csv',index=False)

# %%
competations.to_csv(r'D:\a trainning iti\hadoop\project\new_data\new_competations.csv',index=False)

# %% [markdown]
# # games

# %%
games=pd.read_csv("D:/a trainning iti\hadoop\project\data\games.csv")
games.head()
# Out:
#    game_id competition_id  season        round        date  home_club_id  \
# 0  2321027             L1    2013  1. Matchday  2013-08-11          33.0
# 1  2321033             L1    2013  1. Matchday  2013-08-10          23.0
# 2  2321044             L1    2013  2. Matchday  2013-08-18          16.0
# 3  2321060             L1    2013  3. Matchday  2013-08-25          23.0
# 4  2321072             L1    2013  5. Matchday  2013-09-14          16.0
#
#    away_club_id  home_club_goals  away_club_goals  home_club_position  ...  \
# 0          41.0              3.0              3.0                 8.0  ...
# 1          86.0              0.0              1.0                13.0  ...
# 2          23.0              2.0              1.0                 1.0  ...
# 3          24.0              0.0              2.0                18.0  ...
# 4          41.0              6.0              2.0                 1.0  ...
#
#              stadium attendance         referee  \
# ...

# %%
games['game_id'].duplicated().sum()
# Out:
# 0

# %%
games.isna().sum()
# Out:
# game_id                       0
# competition_id                0
# season                        0
# round                         0
# date                          0
# home_club_id                  9
# away_club_id                  9
# home_club_goals              12
# away_club_goals              12
# home_club_position        22235
# away_club_position        22235
# home_club_manager_name      828
# away_club_manager_name      828
# stadium                     250
# attendance                 9901
# referee                     652
# url                           0
# home_club_formation        6965
# away_club_formation        6796
# home_club_name            12796
# away_club_name            11400
# aggregate                    12
# competition_type              0
# dtype: int64

# %%
games['aggregate']=games['aggregate'].replace(':0','/')

# %%
games.tail()
# Out:
#        game_id competition_id  season                       round        date  \
# 72772  3714107           UCOL    2021  intermediate stage 1st leg  2022-02-17
# 72773  3143618            FAC    2018          Third Round Replay  2019-01-15
# 72774  4233201            SFA    2023                Fourth Round  2024-01-20
# 72775  2469213            ELQ    2014        Second Round 1st leg  2014-07-17
# 72776  2517322            FAC    2014                 Third Round  2015-01-04
#
#        home_club_id  away_club_id  home_club_goals  away_club_goals  \
# 72772         383.0         119.0              1.0              0.0
# 72773         512.0        3054.0              2.0              3.0
# 72774         987.0        3020.0              3.0              1.0
# 72775         987.0       21875.0              2.0              2.0
# 72776         512.0        1112.0              3.0              1.0
#
#        home_club_position  ...          stadium attendance           referee  \
# ...

# %%
games['aggregate'].unique
# Out:
# <bound method Series.unique of 0        3:3
# 1        0:1
# 2        2:1
# 3        0:2
# 4        6:2
#         ...
# 72772    1:0
# 72773    2:3
# 72774    3:1
# 72775    2:2
# 72776    3:1
# Name: aggregate, Length: 72777, dtype: object>

# %%
games.isna().sum()
# Out:
# game_id                       0
# competition_id                0
# season                        0
# round                         0
# date                          0
# home_club_id                  9
# away_club_id                  9
# home_club_goals              12
# away_club_goals              12
# home_club_position        22235
# away_club_position        22235
# home_club_manager_name      828
# away_club_manager_name      828
# stadium                     250
# attendance                 9901
# referee                     652
# url                           0
# home_club_formation        6965
# away_club_formation        6796
# home_club_name            12796
# away_club_name            11400
# aggregate                    12
# competition_type              0
# dtype: int64

# %%
games['stadium']=games['stadium'].fillna('not determined')

# %%
games.isna().sum()
# Out:
# game_id                       0
# competition_id                0
# season                        0
# round                         0
# date                          0
# home_club_id                  9
# away_club_id                  9
# home_club_goals              12
# away_club_goals              12
# home_club_position        22235
# away_club_position        22235
# home_club_manager_name      828
# away_club_manager_name      828
# stadium                       0
# attendance                 9901
# referee                     652
# url                           0
# home_club_formation        6965
# away_club_formation        6796
# home_club_name            12796
# away_club_name            11400
# aggregate                    12
# competition_type              0
# dtype: int64

# %%
games.loc[games['aggregate'].isna(),:]
# Out:
#        game_id competition_id  season           round        date  \
# 69596  4506872           KLUB    2024     Semi-Finals  2025-07-08
# 69639  4506869           KLUB    2024  Quarter-Finals  2025-07-05
# 69699  4506861           KLUB    2024     Round of 16  2025-06-28
# 69700  4506862           KLUB    2024     Round of 16  2025-06-29
# 69701  4506873           KLUB    2024     Semi-Finals  2025-07-09
# 70501  4506864           KLUB    2024     Round of 16  2025-06-30
# 70502  4506867           KLUB    2024     Round of 16  2025-07-02
# 70561  4506874           KLUB    2024           Final  2025-07-13
# 70588  4506868           KLUB    2024  Quarter-Finals  2025-07-04
# 70625  4506860           KLUB    2024     Round of 16  2025-06-28
# 70646  4506871           KLUB    2024  Quarter-Finals  2025-07-05
# 70712  4506870           KLUB    2024  Quarter-Finals  2025-07-05
#
#        home_club_id  away_club_id  home_club_goals  away_club_goals  \
# ...

# %%
games.to_csv(r'D:\a trainning iti\hadoop\project\new_data.csv')

# %%
games.tail()
# Out:
#        game_id competition_id  season                       round        date  \
# 72772  3714107           UCOL    2021  intermediate stage 1st leg  2022-02-17
# 72773  3143618            FAC    2018          Third Round Replay  2019-01-15
# 72774  4233201            SFA    2023                Fourth Round  2024-01-20
# 72775  2469213            ELQ    2014        Second Round 1st leg  2014-07-17
# 72776  2517322            FAC    2014                 Third Round  2015-01-04
#
#        home_club_id  away_club_id  home_club_goals  away_club_goals  \
# 72772         383.0         119.0              1.0              0.0
# 72773         512.0        3054.0              2.0              3.0
# 72774         987.0        3020.0              3.0              1.0
# 72775         987.0       21875.0              2.0              2.0
# 72776         512.0        1112.0              3.0              1.0
#
#        home_club_position  ...          stadium attendance           referee  \
# ...

# %%
games['aggregate']=games['aggregate'].replace(':','/',inplace=True)

# %%
games['aggregate'].value_counts()
# Out:
# aggregate
# 1:1      7221
# 1:0      6909
# 2:1      6068
# 0:1      5496
# 2:0      5414
#          ...
# 5:8         1
# 15:14       1
# 8:3         1
# 8:4         1
# 15:16       1
# Name: count, Length: 117, dtype: int64

# %%
games.isna().sum()
# Out:
# game_id                       0
# competition_id                0
# season                        0
# round                         0
# date                          0
# home_club_id                  9
# away_club_id                  9
# home_club_goals              12
# away_club_goals              12
# home_club_position        22235
# away_club_position        22235
# home_club_manager_name      828
# away_club_manager_name      828
# stadium                       0
# attendance                 9901
# referee                     652
# url                           0
# home_club_formation        6965
# away_club_formation        6796
# home_club_name            12796
# away_club_name            11400
# aggregate                    12
# competition_type              0
# dtype: int64

# %%
games.to_csv(r"D:\a trainning iti\hadoop\project\new_data\new_games.csv")

# %% [markdown]
# # game_lineups

# %% [markdown]
# "D:\a trainning iti\hadoop\project\data\game_lineups.csv"

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Skipping c:\Users\mohse\anaconda3\Lib\site-packages\jupyterlab-3.6.3.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping c:\Users\mohse\anaconda3\Lib\site-packages\jupyterlab_server-2.22.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping c:\Users\mohse\anaconda3\Lib\site-packages\jupyter_server-2.5.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping c:\Users\mohse\anaconda3\Lib\site-packages\nbconvert-6.5.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping c:\Users\mohse\anaconda3\Lib\site-packages\notebook-6.5.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping c:\Users\mohse\anaconda3\Lib\site-packages\panel-1.1.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping c:\Users\mohse\anaconda3\Lib\site-packages\jupyterlab-3.6.3.dist-info due to invalid metadata entry 'name'
# ...

# %%
import pandas as pd

# %%
game_lineups= pd.read_csv("D:/a trainning iti\hadoop\project\data\game_lineups.csv")
game_lineups.head()
# Out:
#                     game_lineups_id        date  game_id  player_id  club_id  \
# 0  b2dbe01c3656b06c8e23e9de714e26bb  2013-07-27  2317258       1443      610
# 1  b50a3ec6d52fd1490aab42042ac4f738  2013-07-27  2317258       5017      610
# 2  7d890e6d0ff8af84b065839966a0ec81  2013-07-27  2317258       9602     1090
# 3  8c355268678b9bbc7084221b1f0fde36  2013-07-27  2317258      12282      610
# 4  76193074d549e5fdce4cdcbba0d66247  2013-07-27  2317258      25427     1090
#
#          player_name             type            position number  team_captain
# 0  Christian Poulsen      substitutes  Defensive Midfield      5             0
# 1   Niklas Moisander  starting_lineup         Centre-Back      4             0
# 2    Maarten Martens      substitutes         Left Winger     11             0
# 3        Daley Blind  starting_lineup           Left-Back     17             0
# 4        Roy Beerens  starting_lineup        Right Winger     23             0

# %%
game_lineups.shape
# Out:
# (2191911, 10)

# %%
game_lineups.isna().sum()
# Out:
# game_lineups_id    0
# date               0
# game_id            0
# player_id          0
# club_id            0
# player_name        0
# type               0
# position           3
# number             0
# team_captain       0
# dtype: int64

# %%
game_lineups['game_lineups_sk'] = range(1, len(game_lineups) + 1)

# %%
game_lineups.loc[len(game_lineups)]=0

# %%
game_lineups[game_lineups['game_lineups_sk']==0]
# Out:
#         game_lineups_id date  game_id  player_id  club_id player_name type  \
# 2191911               0    0        0          0        0           0    0
#
#         position number  team_captain  game_lineups_sk
# 2191911        0      0             0                0

# %%
game_lineups.head()
# Out:
#          date  game_id  player_id  club_id        player_name  \
# 0  2013-07-27  2317258       1443      610  Christian Poulsen
# 1  2013-07-27  2317258       5017      610   Niklas Moisander
# 2  2013-07-27  2317258       9602     1090    Maarten Martens
# 3  2013-07-27  2317258      12282      610        Daley Blind
# 4  2013-07-27  2317258      25427     1090        Roy Beerens
#
#               type            position number  team_captain  game_lineups_sk
# 0      substitutes  Defensive Midfield      5             0                1
# 1  starting_lineup         Centre-Back      4             0                2
# 2      substitutes         Left Winger     11             0                3
# 3  starting_lineup           Left-Back     17             0                4
# 4  starting_lineup        Right Winger     23             0                5

# %%
game_lineups.drop(columns='game_lineups_id',inplace=True)

# %%
print(appearance.columns)
# Out:
# Index(['appearance_id', 'game_id', 'player_id', 'player_club_id',
#        'player_current_club_id', 'date', 'competition_id', 'yellow_cards',
#        'red_cards', 'goals', 'assists', 'minutes_played'],
#       dtype='object')

# %%
appearance.columns
# Out:
# Index(['appearance_id', 'game_id', 'player_id', 'player_club_id',
#        'player_current_club_id', 'date', 'competition_id', 'yellow_cards',
#        'red_cards', 'goals', 'assists', 'minutes_played'],
#       dtype='object')

# %%
game_lineups.columns
# Out:
# Index(['game_lineups_id', 'date', 'game_id', 'player_id', 'club_id',
#        'player_name', 'type', 'position', 'number', 'team_captain'],
#       dtype='object')

# %%
appearance.head()
# Out:
#     appearance_id  game_id  player_id  player_club_id  player_current_club_id  \
# 0   2231978_38004  2231978      38004             853                     235
# 1   2233748_79232  2233748      79232            8841                    2698
# 2   2234413_42792  2234413      42792            6251                     465
# 3   2234418_73333  2234418      73333            1274                    6646
# 4  2234421_122011  2234421     122011             195                    3008
#
#          date  competition_id  yellow_cards  red_cards  goals  assists  \
# 0  2012-07-03              39             0          0      2        0
# 1  2012-07-05              19             0          0      0        0
# 2  2012-07-05              19             0          0      0        0
# 3  2012-07-05              19             0          0      0        0
# 4  2012-07-05              19             0          0      0        1
#
#    minutes_played
# 0              90
# 1              90
# ...

# %%
print(appearance.columns)
print(game_lineups.columns)
# Out:
# Index(['appearance_id', 'game_id', 'player_id', 'player_club_id',
#        'player_current_club_id', 'date', 'competition_id', 'yellow_cards',
#        'red_cards', 'goals', 'assists', 'minutes_played'],
#       dtype='object')
# Index(['game_lineups_id', 'date', 'game_id', 'player_id', 'club_id',
#        'player_name', 'type', 'position', 'number', 'team_captain'],
#       dtype='object')

# %%
import pandas as pd

# Merge appearance_df and game_lineups_df
merged_df = pd.merge(appearance, game_lineups, 
                     how='left', 
                     on=['game_id', 'player_id'], 
                     suffixes=('_appearance', '_game_lineups'))

# Apply the condition for matching club_id with either player_club_id or player_current_club_id
merged_df = merged_df[
    (merged_df['player_club_id'] == merged_df['club_id']) | 
    (merged_df['player_current_club_id'] == merged_df['club_id'])
]

# Select the desired columns from appearance and game_lineups dataframes
result_df = merged_df[['appearance_id', 'game_id', 'player_id', 'player_club_id', 
                       'player_current_club_id', 'date_appearance', 'competition_id', 
                       'yellow_cards', 'red_cards', 'goals', 'assists', 
                       'minutes_played', 'game_lineups_id']]

# If you want to rename the 'date_appearance' column back to 'date'
result_df.rename(columns={'date_appearance': 'date'}, inplace=True)
# Out:
# C:\Users\mohse\AppData\Local\Temp\ipykernel_21756\4086942121.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result_df.rename(columns={'date_appearance': 'date'}, inplace=True)

# %%
result_df.head()
# Out:
#          appearance_id  game_id  player_id  player_club_id  \
# 130736   2321964_30365  2321964      30365            4414
# 130737    2321974_7642  2321974       7642            8841
# 130738   2321961_74587  2321961      74587            8042
# 130739   2321962_55541  2321962      55541             602
# 130740  2321970_133835  2321970     133835            1002
#
#         player_current_club_id        date  competition_id  yellow_cards  \
# 130736                     441  2013-07-02              19             0
# 130737                    6195  2013-07-02              19             0
# 130738                   28956  2013-07-04              19             0
# 130739                    3714  2013-07-04              19             0
# 130740                     499  2013-07-04              19             0
#
#         red_cards  goals  assists  minutes_played  \
# 130736          0      1        0              83
# 130737          0      0        0              90
# ...

# %%
result_df.shape
# Out:
# (1341765, 13)

# %%
appearance.shape
1673842-1341765
# Out:
# 332077

# %%
merged_df.head()  # طباعة أول صفوف من الجدول بعد الدمج
# Out:
#          appearance_id  game_id  player_id  player_club_id  \
# 130736   2321964_30365  2321964      30365            4414
# 130737    2321974_7642  2321974       7642            8841
# 130738   2321961_74587  2321961      74587            8042
# 130739   2321962_55541  2321962      55541             602
# 130740  2321970_133835  2321970     133835            1002
#
#         player_current_club_id date_appearance  competition_id  yellow_cards  \
# 130736                     441      2013-07-02              19             0
# 130737                    6195      2013-07-02              19             0
# 130738                   28956      2013-07-04              19             0
# 130739                    3714      2013-07-04              19             0
# 130740                     499      2013-07-04              19             0
#
#         red_cards  goals  assists  minutes_played  \
# 130736          0      1        0              83
# ...

# %%
# Merge appearance_df and game_lineups_df without filtering
merged_df = pd.merge(appearance, game_lineups, 
                     how='left', 
                     on=['game_id', 'player_id'], 
                     suffixes=('_appearance', '_game_lineups'))

# Select the desired columns from appearance and game_lineups dataframes
result_df = merged_df[['appearance_id', 'game_id', 'player_id', 'player_club_id', 
                       'player_current_club_id', 'date_appearance', 'competition_id', 
                       'yellow_cards', 'red_cards', 'goals', 'assists', 
                       'minutes_played', 'game_lineups_sk']]

# If you want to rename the 'date_appearance' column back to 'date'
result_df.rename(columns={'date_appearance': 'date'}, inplace=True)
# Out:
# C:\Users\mohse\AppData\Local\Temp\ipykernel_21756\975588257.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result_df.rename(columns={'date_appearance': 'date'}, inplace=True)

# %%
result_df.head()
# Out:
#     appearance_id  game_id  player_id  player_club_id  player_current_club_id  \
# 0   2231978_38004  2231978      38004             853                     235
# 1   2233748_79232  2233748      79232            8841                    2698
# 2   2234413_42792  2234413      42792            6251                     465
# 3   2234418_73333  2234418      73333            1274                    6646
# 4  2234421_122011  2234421     122011             195                    3008
#
#          date  competition_id  yellow_cards  red_cards  goals  assists  \
# 0  2012-07-03              39             0          0      2        0
# 1  2012-07-05              19             0          0      0        0
# 2  2012-07-05              19             0          0      0        0
# 3  2012-07-05              19             0          0      0        0
# 4  2012-07-05              19             0          0      0        1
#
#    minutes_played  game_lineups_sk
# ...

# %%
result_df[result_df['game_lineups_sk']==8]
# Out:
#         appearance_id  game_id  player_id  player_club_id  \
# 132439  2317258_34784  2317258      34784             610
#
#         player_current_club_id        date  competition_id  yellow_cards  \
# 132439                     467  2013-07-27               2             0
#
#         red_cards  goals  assists  minutes_played  game_lineups_sk
# 132439          0      0        0              90              8.0

# %%
result_df['game_lineups_sk'].isna().sum()
# Out:
# 331520

# %%
332077
appearance.shape
# Out:
# (1673842, 12)

# %%
result_df['game_lineups_sk'].fillna(0, inplace=True)
# Out:
# C:\Users\mohse\AppData\Local\Temp\ipykernel_21756\4056126633.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result_df['game_lineups_sk'].fillna(0, inplace=True)

# %%
result_df.head()
# Out:
#     appearance_id  game_id  player_id  player_club_id  player_current_club_id  \
# 0   2231978_38004  2231978      38004             853                     235
# 1   2233748_79232  2233748      79232            8841                    2698
# 2   2234413_42792  2234413      42792            6251                     465
# 3   2234418_73333  2234418      73333            1274                    6646
# 4  2234421_122011  2234421     122011             195                    3008
#
#          date  competition_id  yellow_cards  red_cards  goals  assists  \
# 0  2012-07-03              39             0          0      2        0
# 1  2012-07-05              19             0          0      0        0
# 2  2012-07-05              19             0          0      0        0
# 3  2012-07-05              19             0          0      0        0
# 4  2012-07-05              19             0          0      0        1
#
#    minutes_played  game_lineups_sk
# ...

# %%
result_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1673843 entries, 0 to 1673842
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count    Dtype
# ---  ------                  --------------    -----
#  0   appearance_id           1673843 non-null  object
#  1   game_id                 1673843 non-null  int64
#  2   player_id               1673843 non-null  int64
#  3   player_club_id          1673843 non-null  int64
#  4   player_current_club_id  1673843 non-null  int64
#  5   date                    1673843 non-null  object
#  6   competition_id          1673843 non-null  int32
#  7   yellow_cards            1673843 non-null  int64
#  8   red_cards               1673843 non-null  int64
#  9   goals                   1673843 non-null  int64
#  10  assists                 1673843 non-null  int64
#  11  minutes_played          1673843 non-null  int64
#  12  game_lineups_sk         1673843 non-null  int32
# dtypes: int32(2), int64(9), object(2)
# ...

# %%
game_lineups.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 game_lineups.head()
#
# NameError: name 'game_lineups' is not defined

# %%
# تحويل النوع مباشرة إلى int
result_df['game_lineups_sk'] = result_df['game_lineups_sk'].astype(int)
# Out:
# C:\Users\mohse\AppData\Local\Temp\ipykernel_21756\4018936516.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result_df['game_lineups_sk'] = result_df['game_lineups_sk'].astype(int)

# %%
result_df.to_csv(r'D:\a trainning iti\hadoop\project\new_data\new_appearnace.csv')

# %%
game_lineups.to_csv(r'D:\a trainning iti\hadoop\project\new_data\new_game_lineups.csv')

# %%
game_club=pd.read_csv("D:/a trainning iti\hadoop\project\data\club_games.csv")
game_club.head()
# Out:
#    game_id  club_id  own_goals  own_position   own_manager_name  opponent_id  \
# 0  2320450   1468.0        0.0           NaN  Holger Bachthaler         24.0
# 1  2320454    222.0        0.0           NaN        Volkan Uluc         79.0
# 2  2320460      1.0        3.0           NaN    Jürgen Luginger         86.0
# 3  2320472   2036.0        4.0           NaN      Frank Schmidt         72.0
# 4  2321027     33.0        3.0           8.0        Jens Keller         41.0
#
#    opponent_goals  opponent_position opponent_manager_name hosting  is_win
# 0             2.0                NaN             Armin Veh    Home       0
# 1             2.0                NaN        Bruno Labbadia    Home       0
# 2             1.0                NaN            Robin Dutt    Home       1
# 3             5.0                NaN     Alexander Schmidt    Home       0
# 4             3.0                9.0         Thorsten Fink    Home       0

# %%
game_club.duplicated().sum()
# Out:
# 0

# %%
game_club.isna().sum()
# Out:
# game_id                      0
# club_id                      0
# own_goals                    6
# own_position             44452
# own_manager_name          1638
# opponent_id                  0
# opponent_goals               6
# opponent_position        44452
# opponent_manager_name     1638
# hosting                      0
# is_win                       0
# dtype: int64

# %%
game_club.loc[game_club['club_id'].isna()]
# Out:
#         game_id  club_id  own_goals  own_position own_manager_name  \
# 71356   4506869      NaN        NaN           NaN              NaN
# 71642   4506861      NaN        NaN           NaN              NaN
# 71643   4506862      NaN        NaN           NaN              NaN
# 71746   4506864      NaN        NaN           NaN              NaN
# 71747   4506867      NaN        NaN           NaN              NaN
# 72142   4506868      NaN        NaN           NaN              NaN
# 72341   4506860      NaN        NaN           NaN              NaN
# 72421   4506871      NaN        NaN           NaN              NaN
# 72708   4506870      NaN        NaN           NaN              NaN
# 144133  4506869      NaN        NaN           NaN              NaN
# 144419  4506861      NaN        NaN           NaN              NaN
# 144420  4506862      NaN        NaN           NaN              NaN
# 144523  4506864      NaN        NaN           NaN              NaN
# ...

# %%
game_club.dropna(subset=['club_id'], inplace=True)

# %%
game_club.to_csv(r'D:\a trainning iti\hadoop\project\new_data\new_club_games.csv')
